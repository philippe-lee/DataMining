# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
np.set_printoptions(threshold=10000, suppress=True)
warnings.filterwarnings('ignore')
np.random.seed(1)

# %%
wine1 = pd.read_csv("./winemag-data_first150k.csv", header=0, sep=",")
wine2 = pd.read_csv("./winemag-data-130k-v2.csv",header=0,sep=",")
wine1.drop(['Unnamed: 0'],axis=1,inplace=True)
wine2.drop(['Unnamed: 0','taster_name','taster_twitter_handle','title'],axis=1,inplace=True) #pour avoir les
wine=pd.concat([wine1,wine2],axis=0)
wine.drop(wine.loc[wine['country']=='US-France'].index, axis=0,inplace=True) # supprimer la ligne avec le pays US-France
wine.drop_duplicates(keep='first', inplace=True) # supprimer les doublons
wine.reset_index(drop=True, inplace=True) #reset les indices apres avoir retirer les doublons
len(wine)
# Out:
# 170530

# %%
wine.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
wine.tail()
# Out:
#         country                                        description  \
# 170525  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 170526       US  Citation is given as much as a decade of bottl...
# 170527   France  Well-drained gravel soil gives this wine its c...
# 170528   France  A dry style of Pinot Gris, this is crisp with ...
# 170529   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 170525  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 170526                                     NaN      90   75.0   Oregon
# 170527                                   Kritt      90   30.0   Alsace
# 170528                                     NaN      90   32.0   Alsace
# 170529           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         variety  \
# 170525      NaN           NaN        Riesling
# 170526   Oregon  Oregon Other      Pinot Noir
# 170527   Alsace           NaN  Gewürztraminer
# 170528   Alsace           NaN      Pinot Gris
# 170529   Alsace           NaN  Gewürztraminer
#
#                                           winery
# 170525  Dr. H. Thanisch (Erben Müller-Burggraef)
# 170526                                  Citation
# 170527                           Domaine Gresser
# 170528                      Domaine Marcel Deiss
# 170529                          Domaine Schoffit
